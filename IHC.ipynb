# %%
# !sudo apt-get update && sudo apt-get install -y zstd
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Cleaning up old version at /usr/local/lib/ollama
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
# !pip install dspy-ai
# Out:
# Requirement already satisfied: dspy-ai in /usr/local/lib/python3.12/dist-packages (3.1.3)
# Requirement already satisfied: dspy>=3.1.3 in /usr/local/lib/python3.12/dist-packages (from dspy-ai) (3.1.3)
# Requirement already satisfied: openai>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.1.3->dspy-ai) (2.21.0)
# Requirement already satisfied: regex>=2023.10.3 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.1.3->dspy-ai) (2025.11.3)
# Requirement already satisfied: orjson>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.1.3->dspy-ai) (3.11.7)
# Requirement already satisfied: tqdm>=4.66.1 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.1.3->dspy-ai) (4.67.3)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.1.3->dspy-ai) (2.32.4)
# Requirement already satisfied: optuna>=3.4.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.1.3->dspy-ai) (4.7.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.1.3->dspy-ai) (2.12.3)
# Requirement already satisfied: litellm>=1.64.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.1.3->dspy-ai) (1.81.13)
# Requirement already satisfied: diskcache>=5.6.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.1.3->dspy-ai) (5.6.3)
# Requirement already satisfied: json-repair>=0.54.2 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.1.3->dspy-ai) (0.58.0)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.1.3->dspy-ai) (9.1.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from dspy>=3.1.3->dspy-ai) (4.12.1)
# Requirement already satisfied: asyncer==0.0.8 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.1.3->dspy-ai) (0.0.8)
# Requirement already satisfied: cachetools>=5.5.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.1.3->dspy-ai) (7.0.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.1.3->dspy-ai) (3.1.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.1.3->dspy-ai) (2.0.2)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.1.3->dspy-ai) (3.6.0)
# Requirement already satisfied: gepa==0.0.26 in /usr/local/lib/python3.12/dist-packages (from gepa[dspy]==0.0.26->dspy>=3.1.3->dspy-ai) (0.0.26)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio->dspy>=3.1.3->dspy-ai) (3.11)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.12/dist-packages (from anyio->dspy>=3.1.3->dspy-ai) (4.15.0)
# Requirement already satisfied: aiohttp>=3.10 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (3.13.3)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (8.3.1)
# Requirement already satisfied: fastuuid>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (0.14.0)
# Requirement already satisfied: httpx>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (0.28.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (8.7.1)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.23.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (4.26.0)
# Requirement already satisfied: python-dotenv>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (1.2.1)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (0.12.0)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (0.22.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=0.28.1->dspy>=3.1.3->dspy-ai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai>=0.28.1->dspy>=3.1.3->dspy-ai) (0.13.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=0.28.1->dspy>=3.1.3->dspy-ai) (1.3.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy>=3.1.3->dspy-ai) (1.18.4)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy>=3.1.3->dspy-ai) (6.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy>=3.1.3->dspy-ai) (26.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy>=3.1.3->dspy-ai) (2.0.46)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy>=3.1.3->dspy-ai) (6.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dspy>=3.1.3->dspy-ai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dspy>=3.1.3->dspy-ai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dspy>=3.1.3->dspy-ai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->dspy>=3.1.3->dspy-ai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->dspy>=3.1.3->dspy-ai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->dspy>=3.1.3->dspy-ai) (2026.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (1.22.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna>=3.4.0->dspy>=3.1.3->dspy-ai) (1.3.10)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.23.0->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.23.0->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata>=6.8.0->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4.0.0,>=3.1.2->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.23.0->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.23.0->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.23.0->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (0.30.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna>=3.4.0->dspy>=3.1.3->dspy-ai) (3.3.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (1.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (3.21.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (1.2.0)
# Requirement already satisfied: shellingham in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (1.5.4)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (0.23.1)
# Requirement already satisfied: typer>=0.23.1 in /usr/local/lib/python3.12/dist-packages (from typer-slim->huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (0.23.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.23.1->typer-slim->huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.23.1->typer-slim->huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer>=0.23.1->typer-slim->huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer>=0.23.1->typer-slim->huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.23.1->typer-slim->huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy>=3.1.3->dspy-ai) (0.1.2)

# %%
import threading
import subprocess

# Start Ollama service in background

def run_ollama_serve():
  subprocess.Popen(["ollama", "serve"])

thread = threading.Thread(target=run_ollama_serve)
thread.start()

# %%
import dspy
import requests

# %%
def setup_ollama():
  """Configure DSPy to use Ollama."""
  try:
    requests.get("http://localhost:11434/api/tags")
    print("Ollama is running")
  except:
    print("Ollama not running. Start with: ollama serve")
    return False

# %%
dspy.settings.configure(
    lm=dspy.LM(
      model="ollama/gemma3:1b",
      api_base="http://localhost:11434",
      max_tokens=500,
      temperature=0.7,
    )
  )

# %%
import sqlite3

def create_sample_database():
  """Create and populate sample database."""
  conn = sqlite3.connect("company.db")
  c = conn.cursor()

  # Create tables
  c.execute("""
    CREATE TABLE IF NOT EXISTS employees (
      id INTEGER PRIMARY KEY, name TEXT, department TEXT,
      salary INTEGER, hire_date TEXT
    )
  """)

  c.execute("""
    CREATE TABLE IF NOT EXISTS departments (
      id INTEGER PRIMARY KEY, name TEXT,
      budget INTEGER, manager TEXT
    )
  """)

  c.execute("""
    CREATE TABLE IF NOT EXISTS projects (
      id INTEGER PRIMARY KEY, name TEXT, department_id INTEGER,
      budget INTEGER, status TEXT
    )
  """)

  # Insert data
  c.executemany("INSERT OR IGNORE INTO employees VALUES (?, ?, ?, ?, ?)", [
    (1, "Alice Johnson", "Engineering", 95000, "2022-01-15"),
    (2, "Bob Smith", "Sales", 75000, "2021-06-20"),
    (3, "Carol White", "Engineering", 90000, "2023-02-10"),
    (4, "David Brown", "Marketing", 70000, "2022-09-05"),
    (5, "Eve Davis", "Engineering", 98000, "2020-03-12"),
  ])

  c.executemany("INSERT OR IGNORE INTO departments VALUES (?, ?, ?, ?)", [
    (1, "Engineering", 500000, "Alice Johnson"),
    (2, "Sales", 300000, "Bob Smith"),
    (3, "Marketing", 200000, "Carol White"),
  ])

  c.executemany("INSERT OR IGNORE INTO projects VALUES (?, ?, ?, ?, ?)", [
    (1, "API Development", 1, 150000, "In Progress"),
    (2, "Mobile App", 1, 200000, "Planning"),
    (3, "Sales Dashboard", 2, 80000, "Complete"),
  ])

  conn.commit()
  conn.close()
  print("Database created")

# %%
class GenerateSQL(dspy.Signature):
  """Generate SQL from natural language.

  Database schema:
  - employees: id, name, department, salary, hire_date
  - departments: id, name, budget, manager
  - projects: id, name, department_id, budget, status
  """

  question = dspy.InputField(desc="Natural language question")
  sql_query = dspy.OutputField(desc="Valid SQL query")

# %%
class SQLGenerator(dspy.Module):
  """Generate and execute SQL queries with error refinement."""
  def __init__(self):
    super().__init__()
    self.generator = dspy.ChainOfThought(GenerateSQL)
    self.refiner = dspy.ChainOfThought(
      "question, sql_query, error -> refined_sql"
    )

  def forward(self, question, conn):
    # Generate SQL
    output = self.generator(question=question)
    sql = output.sql_query.strip()

    # Try to execute
    try:
      results = conn.execute(sql).fetchall()
      return dspy.Prediction(
        sql_query=sql, results=results, error=None
      )
    except Exception as e:
      # Refine on error
      refined = self.refiner(
        question=question, sql_query=sql, error=str(e)
      )
      try:
        results = conn.execute(refined.refined_sql).fetchall()
        return dspy.Prediction(sql_query=refined.refined_sql, results=results, error=None)
      except Exception as e2:
        return dspy.Prediction(
          sql_query=refined.refined_sql, results=None, error=str(e2)
        )

# %%
def create_examples():
  """Training examples for few-shot learning."""
  return [
    dspy.Example(
      question="How many employees are in the Engineering department?",
      sql_query="SELECT COUNT(*) FROM employees WHERE department = 'Engineering'"
    ).with_inputs("question"),
      dspy.Example(
        question="What is the highest salary in Engineering?",
        sql_query="SELECT MAX(salary) FROM employees WHERE department = 'Engineering'"
      ).with_inputs("question"),
        dspy.Example(
          question="List all employees with salary above 90000",
          sql_query="SELECT name, salary FROM employees WHERE salary > 90000"
        ).with_inputs("question"),
        dspy.Example(
          question="Which department has the highest budget?",
          sql_query="SELECT name, budget FROM departments ORDER BY budget DESC LIMIT 1"
        ).with_inputs("question"),
        dspy.Example(
          question="Show all projects in progress",
          sql_query="SELECT name, budget, status FROM projects WHERE status = 'In Progress'"
        ).with_inputs("question"),
    ]

# %%
setup_ollama()
# Out:
# Ollama is running

# %%
# !ollama pull gemma3:1b

# %%
create_sample_database()
# Out:
# Database created

# %%
# Setup generator with few-shot examples
generator = SQLGenerator()
generator.generator.demos = create_examples()
print("✓ Generator configured with few-shot examples")
# Out:
# ✓ Generator configured with few-shot examples

# %%
conn = sqlite3.connect("company.db")

# %%
test_questions = [
    "How many employees work in Engineering?",
    "What is the average salary of all employees?",
    "Show me all projects with a budget greater than 100000",
    "Which employees have been hired since 2022?",
    "List all managers and their departments",
]

# %%
for i, question in enumerate(test_questions, 1):
    print(f"Query {i}: {question}")
    result = generator.forward(question, conn)
    print(f"SQL: {result.sql_query}")
    print(f"Results: {result.results if not result.error else f' {result.error}'}\n")
# Out:
# 2026/02/19 13:33:06 WARNING dspy.primitives.module: Calling module.forward(...) on SQLGenerator directly is discouraged. Please use module(...) instead.
# 2026/02/19 13:33:06 WARNING dspy.primitives.module: Calling module.forward(...) on SQLGenerator directly is discouraged. Please use module(...) instead.
# Query 1: How many employees work in Engineering?
# SQL: SELECT COUNT(*) FROM employees WHERE department = 'Engineering';
# Results: [(3,)]
#
# Query 2: What is the average salary of all employees?
# SQL: SELECT AVG(salary) FROM employees;
# Results: [(85600.0,)]
#
# Query 3: Show me all projects with a budget greater than 100000
# 2026/02/19 13:33:06 WARNING dspy.primitives.module: Calling module.forward(...) on SQLGenerator directly is discouraged. Please use module(...) instead.
# 2026/02/19 13:33:07 WARNING dspy.primitives.module: Calling module.forward(...) on SQLGenerator directly is discouraged. Please use module(...) instead.
# 2026/02/19 13:33:07 WARNING dspy.primitives.module: Calling module.forward(...) on SQLGenerator directly is discouraged. Please use module(...) instead.
# SQL: SELECT * FROM projects WHERE budget > 100000;
# Results: [(1, 'API Development', 1, 150000, 'In Progress'), (2, 'Mobile App', 1, 200000, 'Planning')]
#
# Query 4: Which employees have been hired since 2022?
# SQL: SELECT * FROM employees WHERE hire_date >= '2022-01-01' AND hire_date < '2023-01-01';
# Results: [(1, 'Alice Johnson', 'Engineering', 95000, '2022-01-15'), (4, 'David Brown', 'Marketing', 70000, '2022-09-05')]
#
# Query 5: List all employees
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#     100     try:
# --> 101         yield
#     102     except Exception as exc:
#
# /usr/local/lib/python3.12/dist-packages/httpx/_transports/default.py in handle_request(self, request)
#     249         with map_httpcore_exceptions():
# --> 250             resp = self._pool.handle_request(req)
#     251
#
# /usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     255             self._close_connections(closing)
# --> 256             raise exc from None
#     257
#
# /usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     235                     # Send the request on the assigned connection.
# --> 236                     response = connection.handle_request(
#     237                         pool_request.request
#
# /usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection.py in handle_request(self, request)
#     100             self._connect_failed = True
# --> 101             raise exc
#     102
#
# /usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection.py in handle_request(self, request)
#      77                 if self._connection is None:
# ---> 78                     stream = self._connect(request)
#      79
#
# /usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection.py in _connect(self, request)
#     123                     with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124                         stream = self._network_backend.connect_tcp(**kwargs)
#     125                         trace.return_value = stream
#
# /usr/local/lib/python3.12/dist-packages/httpcore/_backends/sync.py in connect_tcp(self, host, port, timeout, local_address, socket_options)
#     206
# --> 207         with map_exceptions(exc_map):
#     208             sock = socket.create_connection(
#
# /usr/lib/python3.12/contextlib.py in __exit__(self, typ, value, traceback)
#     157             try:
# --> 158                 self.gen.throw(value)
#     159             except StopIteration as exc:
#
# /usr/local/lib/python3.12/dist-packages/httpcore/_exceptions.py in map_exceptions(map)
#      13             if isinstance(exc, from_exc):
# ---> 14                 raise to_exc(exc) from exc
#      15         raise  # pragma: nocover
#
# ConnectError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/litellm/llms/custom_httpx/llm_http_handler.py in _make_common_sync_call(self, sync_httpx_client, provider_config, api_base, headers, data, timeout, litellm_params, logging_obj, stream, signed_json_body)
#     223             try:
# --> 224                 response = sync_httpx_client.post(
#     225                     url=api_base,
#
# /usr/local/lib/python3.12/dist-packages/litellm/llms/custom_httpx/http_handler.py in post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#    1044         except Exception as e:
# -> 1045             raise e
#    1046
#
# /usr/local/lib/python3.12/dist-packages/litellm/llms/custom_httpx/http_handler.py in post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#    1023                 )
# -> 1024             response = self.client.send(req, stream=stream)
#    1025             response.raise_for_status()
#
# /usr/local/lib/python3.12/dist-packages/httpx/_client.py in send(self, request, stream, auth, follow_redirects)
#     913
# --> 914         response = self._send_handling_auth(
#     915             request,
#
# /usr/local/lib/python3.12/dist-packages/httpx/_client.py in _send_handling_auth(self, request, auth, follow_redirects, history)
#     941             while True:
# --> 942                 response = self._send_handling_redirects(
#     943                     request,
#
# /usr/local/lib/python3.12/dist-packages/httpx/_client.py in _send_handling_redirects(self, request, follow_redirects, history)
#     978
# --> 979             response = self._send_single_request(request)
#     980             try:
#
# /usr/local/lib/python3.12/dist-packages/httpx/_client.py in _send_single_request(self, request)
#    1013         with request_context(request=request):
# -> 1014             response = transport.handle_request(request)
#    1015
#
# /usr/local/lib/python3.12/dist-packages/httpx/_transports/default.py in handle_request(self, request)
#     248         )
# --> 249         with map_httpcore_exceptions():
#     250             resp = self._pool.handle_request(req)
#
# /usr/lib/python3.12/contextlib.py in __exit__(self, typ, value, traceback)
#     157             try:
# --> 158                 self.gen.throw(value)
#     159             except StopIteration as exc:
#
# /usr/local/lib/python3.12/dist-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#     117         message = str(exc)
# --> 118         raise mapped_exc(message) from exc
#     119
#
# ConnectError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# OllamaError                               Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/litellm/main.py in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, verbosity, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, **kwargs)
#    3872
# -> 3873             response = base_llm_http_handler.completion(
#    3874                 model=model,
#
# /usr/local/lib/python3.12/dist-packages/litellm/llms/custom_httpx/llm_http_handler.py in completion(self, model, messages, api_base, custom_llm_provider, model_response, encoding, logging_obj, optional_params, timeout, litellm_params, acompletion, stream, fake_stream, api_key, headers, client, provider_config, shared_session)
#     545
# --> 546         response = self._make_common_sync_call(
#     547             sync_httpx_client=sync_httpx_client,
#
# /usr/local/lib/python3.12/dist-packages/litellm/llms/custom_httpx/llm_http_handler.py in _make_common_sync_call(self, sync_httpx_client, provider_config, api_base, headers, data, timeout, litellm_params, logging_obj, stream, signed_json_body)
#     250             except Exception as e:
# --> 251                 raise self._handle_error(e=e, provider_config=provider_config)
#     252             break
#
# /usr/local/lib/python3.12/dist-packages/litellm/llms/custom_httpx/llm_http_handler.py in _handle_error(self, e, provider_config)
#    4629
# -> 4630         raise provider_config.get_error_class(
#    4631             error_message=error_text,
#
# OllamaError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# APIConnectionError                        Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/litellm/utils.py in wrapper(*args, **kwargs)
#    1568             # MODEL CALL
# -> 1569             result = original_function(*args, **kwargs)
#    1570             end_time = datetime.datetime.now()
#
# /usr/local/lib/python3.12/dist-packages/litellm/main.py in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, verbosity, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, **kwargs)
#    4304         ## Map to OpenAI Exception
# -> 4305         raise exception_type(
#    4306             model=model,
#
# /usr/local/lib/python3.12/dist-packages/litellm/litellm_core_utils/exception_mapping_utils.py in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2397             setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2398             raise e
#    2399         else:
#
# /usr/local/lib/python3.12/dist-packages/litellm/litellm_core_utils/exception_mapping_utils.py in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2366             if hasattr(original_exception, "request"):
# -> 2367                 raise APIConnectionError(
#    2368                     message="{} - {}".format(exception_provider, error_str),
#
# APIConnectionError: litellm.APIConnectionError: OllamaException - [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# APIConnectionError                        Traceback (most recent call last)
# /tmp/ipython-input-3941716047.py in <cell line: 0>()
#       1 for i, question in enumerate(test_questions, 1):
#       2     print(f"Query {i}: {question}")
# ----> 3     result = generator.forward(question, conn)
#       4     print(f"SQL: {result.sql_query}")
#       5     print(f"Results: {result.results if not result.error else f' {result.error}'}\n")
#
# /tmp/ipython-input-526016262.py in forward(self, question, conn)
#      10   def forward(self, question, conn):
#      11     # Generate SQL
# ---> 12     output = self.generator(question=question)
#      13     sql = output.sql_query.strip()
#      14
#
# /usr/local/lib/python3.12/dist-packages/dspy/utils/callback.py in sync_wrapper(instance, *args, **kwargs)
#     324             callbacks = _get_active_callbacks(instance)
#     325             if not callbacks:
# --> 326                 return fn(instance, *args, **kwargs)
#     327
#     328             call_id = uuid.uuid4().hex
#
# /usr/local/lib/python3.12/dist-packages/dspy/primitives/module.py in __call__(self, *args, **kwargs)
#      80                 return output
#      81
# ---> 82             return self.forward(*args, **kwargs)
#      83
#      84     @with_callbacks
#
# /usr/local/lib/python3.12/dist-packages/dspy/predict/chain_of_thought.py in forward(self, **kwargs)
#      37
#      38     def forward(self, **kwargs):
# ---> 39         return self.predict(**kwargs)
#      40
#      41     async def aforward(self, **kwargs):
#
# /usr/local/lib/python3.12/dist-packages/dspy/predict/predict.py in __call__(self, *args, **kwargs)
#     102             raise ValueError(self._get_positional_args_error_message())
#     103
# --> 104         return super().__call__(**kwargs)
#     105
#     106     async def acall(self, *args, **kwargs):
#
# /usr/local/lib/python3.12/dist-packages/dspy/utils/callback.py in sync_wrapper(instance, *args, **kwargs)
#     324             callbacks = _get_active_callbacks(instance)
#     325             if not callbacks:
# --> 326                 return fn(instance, *args, **kwargs)
#     327
#     328             call_id = uuid.uuid4().hex
#
# /usr/local/lib/python3.12/dist-packages/dspy/primitives/module.py in __call__(self, *args, **kwargs)
#      80                 return output
#      81
# ---> 82             return self.forward(*args, **kwargs)
#      83
#      84     @with_callbacks
#
# /usr/local/lib/python3.12/dist-packages/dspy/predict/predict.py in forward(self, **kwargs)
#     196         else:
#     197             with settings.context(send_stream=None):
# --> 198                 completions = adapter(lm, lm_kwargs=config, signature=signature, demos=demos, inputs=kwargs)
#     199
#     200         return self._forward_postprocess(completions, signature, **kwargs)
#
# /usr/local/lib/python3.12/dist-packages/dspy/adapters/chat_adapter.py in __call__(self, lm, lm_kwargs, signature, demos, inputs)
#      84                 # we don't want to retry with a different adapter. Raise the original error instead of the fallback error.
#      85                 raise e
# ---> 86             return JSONAdapter()(lm, lm_kwargs, signature, demos, inputs)
#      87
#      88     async def acall(
#
# /usr/local/lib/python3.12/dist-packages/dspy/adapters/json_adapter.py in __call__(self, lm, lm_kwargs, signature, demos, inputs)
#      71         inputs: dict[str, Any],
#      72     ) -> list[dict[str, Any]]:
# ---> 73         result = self._json_adapter_call_common(lm, lm_kwargs, signature, demos, inputs, super().__call__)
#      74         if result:
#      75             return result
#
# /usr/local/lib/python3.12/dist-packages/dspy/adapters/json_adapter.py in _json_adapter_call_common(self, lm, lm_kwargs, signature, demos, inputs, call_fn)
#      61             # So we fall back to json mode if native function calling is disabled and ToolCalls is present.
#      62             lm_kwargs["response_format"] = {"type": "json_object"}
# ---> 63             return call_fn(lm, lm_kwargs, signature, demos, inputs)
#      64
#      65     def __call__(
#
# /usr/local/lib/python3.12/dist-packages/dspy/adapters/chat_adapter.py in __call__(self, lm, lm_kwargs, signature, demos, inputs)
#      83                 # On context window exceeded error, already using JSONAdapter, or use_json_adapter_fallback is False
#      84                 # we don't want to retry with a different adapter. Raise the original error instead of the fallback error.
# ---> 85                 raise e
#      86             return JSONAdapter()(lm, lm_kwargs, signature, demos, inputs)
#      87
#
# /usr/local/lib/python3.12/dist-packages/dspy/adapters/chat_adapter.py in __call__(self, lm, lm_kwargs, signature, demos, inputs)
#      71     ) -> list[dict[str, Any]]:
#      72         try:
# ---> 73             return super().__call__(lm, lm_kwargs, signature, demos, inputs)
#      74         except Exception as e:
#      75             # fallback to JSONAdapter
#
# /usr/local/lib/python3.12/dist-packages/dspy/adapters/base.py in __call__(self, lm, lm_kwargs, signature, demos, inputs)
#     200         inputs = self.format(processed_signature, demos, inputs)
#     201
# --> 202         outputs = lm(messages=inputs, **lm_kwargs)
#     203         return self._call_postprocess(processed_signature, signature, outputs, lm, lm_kwargs)
#     204
#
# /usr/local/lib/python3.12/dist-packages/dspy/utils/callback.py in sync_wrapper(instance, *args, **kwargs)
#     324             callbacks = _get_active_callbacks(instance)
#     325             if not callbacks:
# --> 326                 return fn(instance, *args, **kwargs)
#     327
#     328             call_id = uuid.uuid4().hex
#
# /usr/local/lib/python3.12/dist-packages/dspy/clients/base_lm.py in __call__(self, prompt, messages, **kwargs)
#      89         **kwargs
#      90     ) -> list[dict[str, Any] | str]:
# ---> 91         response = self.forward(prompt=prompt, messages=messages, **kwargs)
#      92         outputs = self._process_lm_response(response, prompt, messages, **kwargs)
#      93
#
# /usr/local/lib/python3.12/dist-packages/dspy/clients/lm.py in forward(self, prompt, messages, **kwargs)
#     157         completion, litellm_cache_args = self._get_cached_completion_fn(completion, cache)
#     158
# --> 159         results = completion(
#     160             request=dict(model=self.model, messages=messages, **kwargs),
#     161             num_retries=self.num_retries,
#
# /usr/local/lib/python3.12/dist-packages/dspy/clients/cache.py in sync_wrapper(*args, **kwargs)
#     251             # Make a copy of the original request in case it's modified in place, e.g., deleting some fields
#     252             original_request = copy.deepcopy(modified_request)
# --> 253             result = fn(*args, **kwargs)
#     254             # `enable_memory_cache` can be provided at call time to avoid indefinite growth.
#     255             cache.put(original_request, result, ignored_args_for_cache_key, enable_memory_cache)
#
# /usr/local/lib/python3.12/dist-packages/dspy/clients/lm.py in litellm_completion(request, num_retries, cache)
#     358     stream_completion = _get_stream_completion_fn(request, cache, sync=True, headers=headers)
#     359     if stream_completion is None:
# --> 360         return litellm.completion(
#     361             cache=cache,
#     362             num_retries=num_retries,
#
# /usr/local/lib/python3.12/dist-packages/litellm/utils.py in wrapper(*args, **kwargs)
#    1691                     ):
#    1692                         kwargs["num_retries"] = num_retries
# -> 1693                         return litellm.completion_with_retries(*args, **kwargs)
#    1694                 elif (
#    1695                     isinstance(e, litellm.exceptions.ContextWindowExceededError)
#
# /usr/local/lib/python3.12/dist-packages/litellm/main.py in completion_with_retries(*args, **kwargs)
#    4341             stop=tenacity.stop_after_attempt(num_retries), reraise=True
#    4342         )
# -> 4343     return retryer(original_function, *args, **kwargs)
#    4344
#    4345
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     468         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469         while True:
# --> 470             do = self.iter(retry_state=retry_state)
#     471             if isinstance(do, DoAttempt):
#     472                 try:
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in iter(self, retry_state)
#     369         result = None
#     370         for action in self.iter_state.actions:
# --> 371             result = action(retry_state)
#     372         return result
#     373
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in exc_check(rs)
#     411                 retry_exc = self.retry_error_cls(fut)
#     412                 if self.reraise:
# --> 413                     raise retry_exc.reraise()
#     414                 raise retry_exc from fut.exception()
#     415
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in reraise(self)
#     182     def reraise(self) -> t.NoReturn:
#     183         if self.last_attempt.failed:
# --> 184             raise self.last_attempt.result()
#     185         raise self
#     186
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     447                     raise CancelledError()
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#     451                 self._condition.wait(timeout)
#
# /usr/lib/python3.12/concurrent/futures/_base.py in __get_result(self)
#     399         if self._exception:
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#     403                 # Break a reference cycle with the exception in self._exception
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     471             if isinstance(do, DoAttempt):
#     472                 try:
# --> 473                     result = fn(*args, **kwargs)
#     474                 except BaseException:  # noqa: B902
#     475                     retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# /usr/local/lib/python3.12/dist-packages/litellm/utils.py in wrapper(*args, **kwargs)
#    1746                     e, traceback_exception, start_time, end_time
#    1747                 )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1748             raise e
#    1749
#    1750     @wraps(original_function)
#
# /usr/local/lib/python3.12/dist-packages/litellm/utils.py in wrapper(*args, **kwargs)
#    1567                     print_verbose(f"Error while checking max token limit: {str(e)}")
#    1568             # MODEL CALL
# -> 1569             result = original_function(*args, **kwargs)
#    1570             end_time = datetime.datetime.now()
#    1571             if _is_streaming_request(
#
# /usr/local/lib/python3.12/dist-packages/litellm/main.py in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, verbosity, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, **kwargs)
#    4303     except Exception as e:
#    4304         ## Map to OpenAI Exception
# -> 4305         raise exception_type(
#    4306             model=model,
#    4307             custom_llm_provider=custom_llm_provider,
#
# /usr/local/lib/python3.12/dist-packages/litellm/litellm_core_utils/exception_mapping_utils.py in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2396         if exception_mapping_worked:
#    2397             setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2398             raise e
#    2399         else:
#    2400             for error_type in litellm.LITELLM_EXCEPTION_TYPES:
#
# /usr/local/lib/python3.12/dist-packages/litellm/litellm_core_utils/exception_mapping_utils.py in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2365             exception_mapping_worked = True
#    2366             if hasattr(original_exception, "request"):
# -> 2367                 raise APIConnectionError(
#    2368                     message="{} - {}".format(exception_provider, error_str),
#    2369                     llm_provider=custom_llm_provider,
#
# APIConnectionError: litellm.APIConnectionError: OllamaException - [Errno 111] Connection refused
